# %%
# IMPORT Everything here
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
import requests
#from Iconfig import api_Key
#from Iconfig import api_READ_token
import json

# %%
movie_metadata_path = "Resources/movies_metadata.csv"


movie_metadata = pd.read_csv(movie_metadata_path, low_memory = False)


movie_metadata.head(20)
# Out:
#     adult                              belongs_to_collection    budget  \
# 0   False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   False                                                NaN  65000000
# 2   False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3   False                                                NaN  16000000
# 4   False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5   False                                                NaN  60000000
# 6   False                                                NaN  58000000
# 7   False                                                NaN         0
# 8   False                                                NaN  35000000
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 10  False                                                NaN  62000000
# 11  False                                                NaN         0
# 12  False  {'id': 117693, 'name': 'Balto Collection', 'po...         0
# 13  False                                                NaN  44000000
# 14  False                                                NaN  98000000
# 15  False                                                NaN  52000000
# 16  False                                                NaN  16500000
# 17  False                                                NaN   4000000
# 18  False  {'id': 3167, 'name': 'Ace Ventura Collection',...  30000000
# 19  False                                                NaN  60000000
#
#                                                genres  \
# 0   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2   [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                      [{'id': 35, 'name': 'Comedy'}]
# 5   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 6   [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 7   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 8   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 9   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 10  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 11  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# 12  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 13  [{'id': 36, 'name': 'History'}, {'id': 18, 'na...
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 15  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 16  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 17  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...
# 18  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...
# 19  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
#
#                                         homepage     id    imdb_id  \
# 0           http://toystory.disney.com/toy-story    862  tt0114709
# 1                                            NaN   8844  tt0113497
# 2                                            NaN  15602  tt0113228
# 3                                            NaN  31357  tt0114885
# 4                                            NaN  11862  tt0113041
# 5                                            NaN    949  tt0113277
# 6                                            NaN  11860  tt0114319
# 7                                            NaN  45325  tt0112302
# 8                                            NaN   9091  tt0114576
# 9   http://www.mgm.com/view/movie/757/Goldeneye/    710  tt0113189
# 10                                           NaN   9087  tt0112346
# 11                                           NaN  12110  tt0112896
# 12                                           NaN  21032  tt0112453
# 13                                           NaN  10858  tt0113987
# 14                                           NaN   1408  tt0112760
# 15                                           NaN    524  tt0112641
# 16                                           NaN   4584  tt0114388
# 17                                           NaN      5  tt0113101
# 18                                           NaN   9273  tt0112281
# 19                                           NaN  11517  tt0113845
#
#    original_language                  original_title  \
# 0                 en                       Toy Story
# 1                 en                         Jumanji
# 2                 en                Grumpier Old Men
# 3                 en               Waiting to Exhale
# 4                 en     Father of the Bride Part II
# 5                 en                            Heat
# 6                 en                         Sabrina
# 7                 en                    Tom and Huck
# 8                 en                    Sudden Death
# 9                 en                       GoldenEye
# 10                en          The American President
# 11                en     Dracula: Dead and Loving It
# 12                en                           Balto
# 13                en                           Nixon
# 14                en                Cutthroat Island
# 15                en                          Casino
# 16                en           Sense and Sensibility
# 17                en                      Four Rooms
# 18                en  Ace Ventura: When Nature Calls
# 19                en                     Money Train
#
#                                              overview  ... release_date  \
# 0   Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1   When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2   A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3   Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4   Just when George Banks has recovered from his ...  ...   1995-02-10
# 5   Obsessive master thief, Neil McCauley leads a ...  ...   1995-12-15
# 6   An ugly duckling having undergone a remarkable...  ...   1995-12-15
# 7   A mischievous young boy, Tom Sawyer, witnesses...  ...   1995-12-22
# 8   International action superstar Jean Claude Van...  ...   1995-12-22
# 9   James Bond must unmask the mysterious head of ...  ...   1995-11-16
# 10  Widowed U.S. president Andrew Shepherd, one of...  ...   1995-11-17
# 11  When a lawyer shows up at the vampire's doorst...  ...   1995-12-22
# 12  An outcast half-wolf risks his life to prevent...  ...   1995-12-22
# 13  An all-star cast powers this epic look at Amer...  ...   1995-12-22
# 14  Morgan Adams and her slave, William Shaw, are ...  ...   1995-12-22
# 15  The life of the gambling paradise – Las Vegas ...  ...   1995-11-22
# 16  Rich Mr. Dashwood dies, leaving his second wif...  ...   1995-12-13
# 17  It's Ted the Bellhop's first night on the job....  ...   1995-12-09
# 18  Summoned from an ashram in Tibet, Ace finds hi...  ...   1995-11-10
# 19  A vengeful New York transit cop decides to ste...  ...   1995-11-21
#
#         revenue runtime                                   spoken_languages  \
# 0   373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1   262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2           0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3    81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4    76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 5   187436818.0   170.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 6           0.0   127.0  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...
# 7           0.0    97.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 8    64350171.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 9   352194034.0   130.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 10  107879496.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 11          0.0    88.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 12   11348324.0    78.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 13   13681765.0   192.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 14   10017322.0   119.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 15  116112375.0   178.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 16  135000000.0   136.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 17    4300000.0    98.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 18  212385533.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 19   35431113.0   103.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#       status                                            tagline  \
# 0   Released                                                NaN
# 1   Released          Roll the dice and unleash the excitement!
# 2   Released  Still Yelling. Still Fighting. Still Ready for...
# 3   Released  Friends are the people who let you be yourself...
# 4   Released  Just When His World Is Back To Normal... He's ...
# 5   Released                           A Los Angeles Crime Saga
# 6   Released  You are cordially invited to the most surprisi...
# 7   Released                             The Original Bad Boys.
# 8   Released                         Terror goes into overtime.
# 9   Released               No limits. No fears. No substitutes.
# 10  Released  Why can't the most powerful man in the world h...
# 11  Released                                                NaN
# 12  Released                     Part Dog. Part Wolf. All Hero.
# 13  Released  Triumphant in Victory, Bitter in Defeat. He Ch...
# 14  Released  The Course Has Been Set. There Is No Turning B...
# 15  Released                   No one stays at the top forever.
# 16  Released           Lose your heart and come to your senses.
# 17  Released  Twelve outrageous guests. Four scandalous requ...
# 18  Released            New animals. New adventures. Same hair.
# 19  Released                        Get on, or GET OUT THE WAY!
#
#                              title  video vote_average vote_count
# 0                        Toy Story  False          7.7     5415.0
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# 5                             Heat  False          7.7     1886.0
# 6                          Sabrina  False          6.2      141.0
# 7                     Tom and Huck  False          5.4       45.0
# 8                     Sudden Death  False          5.5      174.0
# 9                        GoldenEye  False          6.6     1194.0
# 10          The American President  False          6.5      199.0
# 11     Dracula: Dead and Loving It  False          5.7      210.0
# 12                           Balto  False          7.1      423.0
# 13                           Nixon  False          7.1       72.0
# 14                Cutthroat Island  False          5.7      137.0
# 15                          Casino  False          7.8     1343.0
# 16           Sense and Sensibility  False          7.2      364.0
# 17                      Four Rooms  False          6.5      539.0
# 18  Ace Ventura: When Nature Calls  False          6.1     1128.0
# 19                     Money Train  False          5.4      224.0
#
# [20 rows x 24 columns]

# %%
movie_metadata_df =  movie_metadata[["title", "imdb_id", "genres", "release_date", "budget", "revenue", "runtime", "vote_average", "vote_count", "production_companies"]]

movie_metadata_df.head(20)
# Out:
#                              title    imdb_id  \
# 0                        Toy Story  tt0114709
# 1                          Jumanji  tt0113497
# 2                 Grumpier Old Men  tt0113228
# 3                Waiting to Exhale  tt0114885
# 4      Father of the Bride Part II  tt0113041
# 5                             Heat  tt0113277
# 6                          Sabrina  tt0114319
# 7                     Tom and Huck  tt0112302
# 8                     Sudden Death  tt0114576
# 9                        GoldenEye  tt0113189
# 10          The American President  tt0112346
# 11     Dracula: Dead and Loving It  tt0112896
# 12                           Balto  tt0112453
# 13                           Nixon  tt0113987
# 14                Cutthroat Island  tt0112760
# 15                          Casino  tt0112641
# 16           Sense and Sensibility  tt0114388
# 17                      Four Rooms  tt0113101
# 18  Ace Ventura: When Nature Calls  tt0112281
# 19                     Money Train  tt0113845
#
#                                                genres release_date    budget  \
# 0   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...   1995-10-30  30000000
# 1   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   1995-12-15  65000000
# 2   [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   1995-12-22         0
# 3   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   1995-12-22  16000000
# 4                      [{'id': 35, 'name': 'Comedy'}]   1995-02-10         0
# 5   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...   1995-12-15  60000000
# 6   [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...   1995-12-15  58000000
# 7   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...   1995-12-22         0
# 8   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...   1995-12-22  35000000
# 9   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...   1995-11-16  58000000
# 10  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   1995-11-17  62000000
# 11  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...   1995-12-22         0
# 12  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...   1995-12-22         0
# 13  [{'id': 36, 'name': 'History'}, {'id': 18, 'na...   1995-12-22  44000000
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...   1995-12-22  98000000
# 15  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...   1995-11-22  52000000
# 16  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...   1995-12-13  16500000
# 17  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...   1995-12-09   4000000
# 18  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...   1995-11-10  30000000
# 19  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...   1995-11-21  60000000
#
#         revenue  runtime  vote_average  vote_count  \
# 0   373554033.0     81.0           7.7      5415.0
# 1   262797249.0    104.0           6.9      2413.0
# 2           0.0    101.0           6.5        92.0
# 3    81452156.0    127.0           6.1        34.0
# 4    76578911.0    106.0           5.7       173.0
# 5   187436818.0    170.0           7.7      1886.0
# 6           0.0    127.0           6.2       141.0
# 7           0.0     97.0           5.4        45.0
# 8    64350171.0    106.0           5.5       174.0
# 9   352194034.0    130.0           6.6      1194.0
# 10  107879496.0    106.0           6.5       199.0
# 11          0.0     88.0           5.7       210.0
# 12   11348324.0     78.0           7.1       423.0
# 13   13681765.0    192.0           7.1        72.0
# 14   10017322.0    119.0           5.7       137.0
# 15  116112375.0    178.0           7.8      1343.0
# 16  135000000.0    136.0           7.2       364.0
# 17    4300000.0     98.0           6.5       539.0
# 18  212385533.0     90.0           6.1      1128.0
# 19   35431113.0    103.0           5.4       224.0
#
#                                  production_companies
# 0      [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1   [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2   [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3   [{'name': 'Twentieth Century Fox Film Corporat...
# 4   [{'name': 'Sandollar Productions', 'id': 5842}...
# 5   [{'name': 'Regency Enterprises', 'id': 508}, {...
# 6   [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 7         [{'name': 'Walt Disney Pictures', 'id': 2}]
# 8   [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 9   [{'name': 'United Artists', 'id': 60}, {'name'...
# 10  [{'name': 'Columbia Pictures', 'id': 5}, {'nam...
# 11  [{'name': 'Columbia Pictures', 'id': 5}, {'nam...
# 12  [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 13  [{'name': 'Hollywood Pictures', 'id': 915}, {'...
# 14  [{'name': 'Le Studio Canal+', 'id': 183}, {'na...
# 15  [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 16  [{'name': 'Columbia Pictures Corporation', 'id...
# 17  [{'name': 'Miramax Films', 'id': 14}, {'name':...
# 18  [{'name': 'O Entertainment', 'id': 5682}, {'na...
# 19           [{'name': 'Columbia Pictures', 'id': 5}]

# %%
## We only want movies between 2007 and 2017 that people paid to see  ##
movie_metadata_df = movie_metadata_df.loc[ (movie_metadata_df["release_date"] >= "2005-01-01") & (movie_metadata_df["release_date"] <= "2018-12-31") & (movie_metadata_df["revenue"] != 0), :]


movie_metadata_df.head(20)
# Out:
#                         title    imdb_id  \
# 4356     Camille Claudel 1915  tt2018086
# 11155              Black Gold  tt1701210
# 11472         Freedom Writers  tt0463998
# 11497  Code Name: The Cleaner  tt0462229
# 11498          Stomp the Yard  tt0775539
# 11519                Primeval  tt0772193
# 11521             The Hitcher  tt0455960
# 11537    Bridge to Terabithia  tt0398808
# 11547                Waitress  tt0473308
# 11557              Epic Movie  tt0799949
# 11558          The Messengers  tt0425430
# 11559       Because I Said So  tt0490084
# 11560         Hannibal Rising  tt0367959
# 11561                  Norbit  tt0477051
# 11567             Ratatouille  tt0382932
# 11592             Ghost Rider  tt0259324
# 11593                  Breach  tt0401997
# 11594    Daddy's Little Girls  tt0778661
# 11595        Music and Lyrics  tt0758766
# 11596           The Number 23  tt0481369
#
#                                                   genres release_date  \
# 4356                       [{'id': 18, 'name': 'Drama'}]   2013-03-13
# 11155  [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...   2011-12-21
# 11472  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...   2007-01-05
# 11497  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...   2007-01-05
# 11498  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...   2007-05-16
# 11519                  [{'id': 12, 'name': 'Adventure'}]   2007-01-12
# 11521  [{'id': 28, 'name': 'Action'}, {'id': 27, 'nam...   2007-01-19
# 11537  [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...   2007-02-16
# 11547                     [{'id': 35, 'name': 'Comedy'}]   2007-05-25
# 11557  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...   2007-01-25
# 11558  [{'id': 9648, 'name': 'Mystery'}, {'id': 53, '...   2007-02-02
# 11559                     [{'id': 35, 'name': 'Comedy'}]   2007-02-02
# 11560  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...   2007-02-06
# 11561                     [{'id': 35, 'name': 'Comedy'}]   2007-02-08
# 11567  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...   2007-06-22
# 11592  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...   2007-02-16
# 11593  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...   2007-02-12
# 11594  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   2007-02-14
# 11595  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...   2007-02-09
# 11596  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...   2007-02-23
#
#           budget      revenue  runtime  vote_average  vote_count  \
# 4356     3512454     115860.0     95.0           7.0        20.0
# 11155   40000000    5446000.0    130.0           5.9        77.0
# 11472   21000000   41170784.0    123.0           7.6       368.0
# 11497   20000000   10337477.0     84.0           4.7        78.0
# 11498   13000000   75511123.0    114.0           6.1        90.0
# 11519          0   10597734.0     93.0           4.7        45.0
# 11521   10000000   25399945.0     84.0           5.6       253.0
# 11537   60000000  137587063.0     96.0           7.0      1146.0
# 11547    2000000   22179430.0    108.0           6.6       132.0
# 11557   20000000   86865564.0     86.0           3.2       334.0
# 11558   16000000    1109660.0     90.0           5.6       216.0
# 11559          0   69485490.0    102.0           5.8       194.0
# 11560   50000000   82169884.0    121.0           6.0       666.0
# 11561   60000000   95673607.0    101.0           5.0       434.0
# 11567  150000000  623722818.0    111.0           7.5      4510.0
# 11592  110000000  228738393.0    114.0           5.2      1754.0
# 11593          0   33231264.0    110.0           6.5       174.0
# 11594   10000000   31609243.0    100.0           6.6        19.0
# 11595   40000000  145896422.0     96.0           6.2       569.0
# 11596   30000000   77566815.0    101.0           6.3      1045.0
#
#                                     production_companies
# 4356   [{'name': 'Canal+', 'id': 5358}, {'name': 'Art...
# 11155  [{'name': 'France 2 Cinéma', 'id': 83}, {'name...
# 11472  [{'name': 'Double Feature Films', 'id': 215}, ...
# 11497            [{'name': 'New Line Cinema', 'id': 12}]
# 11498         [{'name': 'Rainforest Films', 'id': 1309}]
# 11519  [{'name': 'Hollywood Pictures', 'id': 915}, {'...
# 11521  [{'name': 'Intrepid Pictures', 'id': 1224}, {'...
# 11537  [{'name': 'Walden Media', 'id': 10221}, {'name...
# 11547  [{'name': 'Night and Day Pictures', 'id': 24133}]
# 11557  [{'name': 'Twentieth Century Fox Film Corporat...
# 11558  [{'name': 'Columbia Pictures', 'id': 5}, {'nam...
# 11559  [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 11560  [{'name': 'Ingenious Film Partners', 'id': 289...
# 11561  [{'name': 'DreamWorks SKG', 'id': 27}, {'name'...
# 11567  [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
# 11592  [{'name': 'Columbia Pictures Corporation', 'id...
# 11593  [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 11594  [{'name': 'Lions Gate Films', 'id': 35}, {'nam...
# 11595  [{'name': 'Village Roadshow Pictures', 'id': 7...
# 11596  [{'name': 'New Line Cinema', 'id': 12}, {'name...

# %%
print(f"The movie database contains {len(movie_metadata_df)} movies that match our criteria.")
# Out:
# The movie database contains 3096 movies that match our criteria.

# %%
### Just for fun, separated movies by release year ###
    ## Note that the numerals denote year of data ##

moviesVII_df = movie_metadata_df.loc[ (movie_metadata_df["release_date"] >= "2007-01-01") & (movie_metadata_df["release_date"] <= "2007-12-31"), :]
moviesVIII_df = movie_metadata_df.loc[ (movie_metadata_df["release_date"] >= "2008-01-01") & (movie_metadata_df["release_date"] <= "2008-12-31"), :]
moviesIX_df = movie_metadata_df.loc[ (movie_metadata_df["release_date"] >= "2009-01-01") & (movie_metadata_df["release_date"] <= "2009-12-31"), :]
moviesX_df = movie_metadata_df.loc[ (movie_metadata_df["release_date"] >= "2010-01-01") & (movie_metadata_df["release_date"] <= "2010-12-31"), :]
moviesXI_df = movie_metadata_df.loc[ (movie_metadata_df["release_date"] >= "2011-01-01") & (movie_metadata_df["release_date"] <= "2011-12-31"), :]
moviesXII_df = movie_metadata_df.loc[ (movie_metadata_df["release_date"] >= "2012-01-01") & (movie_metadata_df["release_date"] <= "2012-12-31"), :]
moviesXIII_df = movie_metadata_df.loc[ (movie_metadata_df["release_date"] >= "2013-01-01") & (movie_metadata_df["release_date"] <= "2013-12-31"), :]
moviesXIV_df = movie_metadata_df.loc[ (movie_metadata_df["release_date"] >= "2014-01-01") & (movie_metadata_df["release_date"] <= "2014-12-31"), :]
moviesXV_df = movie_metadata_df.loc[ (movie_metadata_df["release_date"] >= "2015-01-01") & (movie_metadata_df["release_date"] <= "2015-12-31"), :]
moviesXVI_df = movie_metadata_df.loc[ (movie_metadata_df["release_date"] >= "2016-01-01") & (movie_metadata_df["release_date"] <= "2016-12-31"), :]
moviesXVII_df = movie_metadata_df.loc[ (movie_metadata_df["release_date"] >= "2017-01-01") & (movie_metadata_df["release_date"] <= "2017-12-31"), :]

# %%
# Here's how many movies this csv catalogues per year, from 2007 to 2017 ##
movieYearList = [len(moviesVII_df["imdb_id"]), len(moviesVIII_df["imdb_id"]), len(moviesIX_df["imdb_id"]), len(moviesX_df["imdb_id"]), len(moviesXI_df["imdb_id"]), len(moviesXII_df["imdb_id"]), len(moviesXIII_df["imdb_id"]), len(moviesXIV_df["imdb_id"]), len(moviesXV_df["imdb_id"]), len(moviesXVI_df["imdb_id"]), len(moviesXVII_df["imdb_id"]) ]
movieYearList
# Out:
# [258, 266, 284, 306, 312, 305, 337, 321, 310, 299, 98]
